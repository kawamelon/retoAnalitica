# %% [markdown]
# Ana Valeria Pérez Pérez - A01747541
#
# Daniel Nava Mondragón - A01661649
#
# José Francisco Lara Delgado - A01662659

# %%
import pandas as pd
import numpy as np
import date as dt

# %%
df = pd.read_csv('covid19_tweets.csv')
df
# Out:
#                       user_name         user_location  \
# 0                        ᏉᎥ☻լꂅϮ            astroworld
# 1                 Tom Basile 🇺🇸          New York, NY
# 2               Time4fisticuffs      Pewee Valley, KY
# 3                   ethel mertz  Stuck in the Middle
# 4                      DIPR-J&K     Jammu and Kashmir
# ...                         ...                   ...
# 74431             Laura Wolfrom         Lexington, KY
# 74432  Professor Tonya M. Evans         😷 #stayathome
# 74433        People's Daily app           北京, 中华人民共和国
# 74434                     M0ser                   NaN
# 74435    Your Friend & Sabre ⚔️           Chicago, IL
#
#                                         user_description         user_created  \
# 0      wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1      Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2      #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# ...

# %%
col1 = df["user_followers"]
col2 = df["user_friends"]
col3 = df["user_favourites"]

de1 = np.std(col1)
de2 = np.std(col2)
de3 = np.std(col3)

print("La desviación estándar de la lista user_followers es: ", de1)
print("\nLa desviación estándar de la lista user_friends es: ", de2)
print("\nLa desviación estándar de la lista user_favourites es: ", de3)
# Out:
# La desviación estándar de la lista user_followers es:  822284.4620050807
#
# La desviación estándar de la lista user_friends es:  9365.524563197956
#
# La desviación estándar de la lista user_favourites es:  46689.400666605405

# %%
median1 = col1.median(axis=0)
median2 = col2.median(axis=0)
median3 = col3.median(axis=0)

print("La mediana de la lista user_followers es: ", median1)
print("\nLa mediana de la lista user_friends es: ", median2)
print("\nLa mediana de la lista user_favourites es: ", median3)
# Out:
# La mediana de la lista user_followers es:  960.0
#
# La mediana de la lista user_friends es:  552.0
#
# La mediana de la lista user_favourites es:  1927.0

# %%
prom1 = col1.mean()
prom2 = col2.mean()
prom3 = col3.mean()

print("La media de la lista user_followers es: ", prom1)
print("\nLa media de la lista user_friends es: ", prom2)
print("\nLa media de la lista user_favourites es: ", prom3)
# Out:
# La media de la lista user_followers es:  105951.31291310657
#
# La media de la lista user_friends es:  2154.7211698640444
#
# La media de la lista user_favourites es:  15297.472029663066

# %% [markdown]
# # Conclusiones
