# %% [markdown]
# # **Carga dataframe**

# %%
ls
# Out:
# covid19_tweets.csv  sample_data/

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_c=pd.read_csv("covid19_tweets.csv")
data_c
# Out:
#                       user_name         user_location  \
# 0                        ᏉᎥ☻լꂅϮ            astroworld
# 1                 Tom Basile 🇺🇸          New York, NY
# 2               Time4fisticuffs      Pewee Valley, KY
# 3                   ethel mertz  Stuck in the Middle
# 4                      DIPR-J&K     Jammu and Kashmir
# ...                         ...                   ...
# 74431             Laura Wolfrom         Lexington, KY
# 74432  Professor Tonya M. Evans         😷 #stayathome
# 74433        People's Daily app           北京, 中华人民共和国
# 74434                     M0ser                   NaN
# 74435    Your Friend & Sabre ⚔️           Chicago, IL
#
#                                         user_description         user_created  \
# 0      wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1      Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2      #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# ...

# %%
data_c.shape
# Out:
# (74436, 13)

# %% [markdown]
# # **Nueva tabla para hacer el analisis**

# %%
new_data = data_c[['user_name','user_followers','user_location','user_verified']]
new_data
# Out:
#                       user_name  user_followers         user_location  \
# 0                        ᏉᎥ☻լꂅϮ             624            astroworld
# 1                 Tom Basile 🇺🇸            2253          New York, NY
# 2               Time4fisticuffs            9275      Pewee Valley, KY
# 3                   ethel mertz             197  Stuck in the Middle
# 4                      DIPR-J&K          101009     Jammu and Kashmir
# ...                         ...             ...                   ...
# 74431             Laura Wolfrom              85         Lexington, KY
# 74432  Professor Tonya M. Evans            4289         😷 #stayathome
# 74433        People's Daily app            1413           北京, 中华人民共和国
# 74434                     M0ser            2554                   NaN
# 74435    Your Friend & Sabre ⚔️             310           Chicago, IL
#
#        user_verified
# 0              False
# 1               True
# 2              False
# 3              False
# ...

# %% [markdown]
# # **Tabla de orden descendente de followers**

# %%
new_data = new_data.sort_values(by='user_followers', ascending=False)
new_data
# Out:
#                   user_name  user_followers   user_location  user_verified
# 6959                   CGTN        13892841  Beijing, China           True
# 13450                  CGTN        13892839  Beijing, China           True
# 16194                  CGTN        13892837  Beijing, China           True
# 235                    CGTN        13892795  Beijing, China           True
# 2837                   CGTN        13892793  Beijing, China           True
# ...                     ...             ...             ...            ...
# 54006            kimberly s               0             NaN          False
# 23222           Barry Kerry               0         Bristol          False
# 59125                    小D               0             NaN          False
# 6084   Medilight Healthcare               0             NaN          False
# 28203       whatis315229419               0             NaN          False
#
# [74436 rows x 4 columns]

# %% [markdown]
# # **Tabla para eliminar repeticiones de user_name y dejar el que tenga mayor numero de followers**

# %%
new_data = new_data.drop_duplicates(subset='user_name', keep='first')
new_data
# Out:
#                   user_name  user_followers                  user_location  \
# 6959                   CGTN        13892841                 Beijing, China
# 73350                  NDTV        13449823                          India
# 70675    The Times Of India        12997738                      New Delhi
# 52315        United Nations        12765688                   New York, NY
# 22551     China Xinhua News        12681192  Headquartered in Beijing, PRC
# ...                     ...             ...                            ...
# 8025          Secret Locker               0                            NaN
# 44527                  Abby               0                            NaN
# 23222           Barry Kerry               0                        Bristol
# 59125                    小D               0                            NaN
# 6084   Medilight Healthcare               0                            NaN
#
#        user_verified
# 6959            True
# 73350           True
# ...

# %% [markdown]
# # **Tabla Influencers**
# *10.000 a 100.000 seguidores*

# %%
inf_10mil = []
inf_10mil = (new_data[new_data["user_followers"] < 99999])
inf_10mil = (inf_10mil[inf_10mil["user_followers"] > 9999])
inf_10mil.sort_values("user_followers", ascending=False)
# Out:
#                   user_name  user_followers               user_location  \
# 73845       Linda Girgis MD           99873             South River, NJ
# 55394     Dr. Rajiv J. Shah           99852                      NYC/DC
# 46568                KPIX 5           99804      San Francisco Bay Area
# 61140  Democratic Governors           99739              Washington, DC
# 40406  The New Humanitarian           99644         Geneva, Switzerland
# ...                     ...             ...                         ...
# 12169  Claire Wakefield PhD           10010  Sydney NSW 2052, Australia
# 62933         NorthEast Now           10008              गुवाहाटी, भारत
# 40068          JV Taco 🇺🇸🇻🇪           10006                         NaN
# 24547  McHugh Disney Madnss           10004                 Chicago, IL
# 18764         NHS Devon CCG           10000                   Devon, UK
#
#        user_verified
# 73845           True
# 55394           True
# 46568           True
# ...

# %% [markdown]
# Analisis estadisitico

# %%
media = np.mean(inf_10mil['user_followers'])
print('Media aritmetica:', media)

mediana = np.median(inf_10mil['user_followers'])
print("Mediana:", mediana)

desv = np.std(inf_10mil['user_followers'])
print("desviacion estandar:", desv)
print()
sns.boxplot(inf_10mil, showfliers=False)
# Out:
# Media aritmetica: 28754.881741712023
# Mediana: 20644.5
# desviacion estandar: 20431.356243974653
# <Axes: >

# %% [markdown]
# En este rango, no podemos ver mucha diferencia entre las primeras cuentas con más seguidores. De igual manera, también podemos observar como el tipo de cuentas que se encuentran aquí, son cuentas personales.

# %% [markdown]
# # **Tabla de Macroinfluencers**

# %% [markdown]
# *100 000 a 500 000 seguidores*

# %%
inf_100mil = []
inf_100mil = new_data[new_data["user_followers"] > 99999]
inf_100mil = (inf_100mil[inf_100mil["user_followers"] < 499999])
inf_100mil.sort_values("user_followers", ascending=False)
# Out:
#                                              user_name  user_followers  \
# 51595                                  Warren Whitlock          499645
# 46459                                  Face The Nation          495534
# 436                                    Raza Ahmad Rumi          492605
# 50615  Johns Hopkins Bloomberg School of Public Health          490854
# 62866                                    Anthony Casas          490705
# ...                                                ...             ...
# 15531                                  Spiros Margaris          100849
# 62843                               Los Angeles County          100763
# 8799   International Fund for Agricultural Development          100634
# 67854                     Hamzat Lawal💡Hamzy! {Etim} 🔦          100446
# 9840                                Sri Lanka Tweet 🇱🇰          100426
#
#             user_location  user_verified
# 51595       Las Vegas, NV           True
# ...

# %%
media = np.mean(inf_100mil['user_followers'])
print('Media aritmetica:', media)

mediana = np.median(inf_100mil['user_followers'])
print("Mediana:", mediana)

desv = np.std(inf_100mil['user_followers'])
print("desviacion estandar:", desv)
print()
sns.boxplot(inf_100mil, showfliers=False)
# Out:
# Media aritmetica: 209495.01901743264
# Mediana: 177520.0
# desviacion estandar: 99810.46922487784
# <Axes: >

# %% [markdown]
# Misma situación que el caso anterior, con la diferencia de que aquí empiezan a aparecer figuras políticas regionales

# %% [markdown]
# # **Tabla de Megainfluencers**

# %% [markdown]
# *500 000 a 1 500 000 seguidores*

# %%
inf_500mil = []
inf_500mil = new_data[new_data["user_followers"] > 500000]
inf_500mil = (inf_500mil[inf_500mil["user_followers"] < 1500000])
inf_500mil.sort_values("user_followers", ascending=False)
# Out:
#                 user_name  user_followers                  user_location  \
# 69690       Digital India         1470499               New Delhi, Delhi
# 21854          Maya Karin         1469211                            NaN
# 65215           U.S. Navy         1440093                    The 7 seas!
# 27065       Premium Times         1411832                 Abuja, Nigeria
# 14735      DZMM TeleRadyo         1398375  ABS-CBN, Diliman, Quezon City
# ...                   ...             ...                            ...
# 18613           Doha News          512119                    Doha, Qatar
# 67094           TRS Party          502610           Hyderabad, Telangana
# 71056   TheNationThailand          501409               Bangkok Thailand
# 9624   The Gov't of Japan          500871                            NaN
# 37234           Flipboard          500070                      Palo Alto
#
#        user_verified
# 69690           True
# 21854           True
# 65215           True
# ...

# %%
media = np.mean(inf_500mil['user_followers'])
print('Media aritmetica:', media)

mediana = np.median(inf_500mil['user_followers'])
print("Mediana:", mediana)

desv = np.std(inf_500mil['user_followers'])
print("desviacion estandar:", desv)
print()
sns.boxplot(inf_500mil, showfliers=False)
# Out:
# Media aritmetica: 818813.2727272727
# Mediana: 744506.0
# desviacion estandar: 256497.31354650672
# <Axes: >

# %% [markdown]
# Una vez más, el caso de las dos gráficas anteriores se repite, además de que empezamos a notar que ahora existen cuentas de medios de comunicación y figuras políticas importantes.

# %% [markdown]
# # **Tabla de famosos**

# %% [markdown]
# *Más de 1 500 000*

# %%
inf_1mill = []
inf_1mill = new_data[new_data["user_followers"] > 1499999]
inf_1mill.sort_values("user_followers", ascending=False)
# Out:
#                  user_name  user_followers                  user_location  \
# 6959                  CGTN        13892841                 Beijing, China
# 73350                 NDTV        13449823                          India
# 70675   The Times Of India        12997738                      New Delhi
# 52315       United Nations        12765688                   New York, NY
# 22551    China Xinhua News        12681192  Headquartered in Beijing, PRC
# ...                    ...             ...                            ...
# 63805             The Star         1629758         Kuala Lumpur, Malaysia
# 39767  The Weather Network         1611719                         Canada
# 2897         NelsonMandela         1591819         Houghton, South Africa
# 59360        Rickey Smiley         1559781                            NaN
# 73255       UN Development         1543135    170 countries & territories
#
#        user_verified
# 6959            True
# 73350           True
# ...

# %%
media = np.mean(inf_1mill['user_followers'])
print('Media aritmetica:', media)

mediana = np.median(inf_1mill['user_followers'])
print("Mediana:", mediana)

desv = np.std(inf_1mill['user_followers'])
print("desviacion estandar:", desv)
print()
sns.boxplot(inf_1mill, showfliers=False)
# Out:
# Media aritmetica: 4307630.5
# Mediana: 3134602.0
# desviacion estandar: 3078495.0541586177
# <Axes: >

# %% [markdown]
# En esta gráfica se nos muestra el nombre de las cuentas que cuentan con más seguidores. De estos datos, podemos decir que las cuentas que tienen más seguidores son principalmente medios de comunicación (cadenas de televisión y periódicos) e instituciones gubernamentales. Sin embargo existen dos datos anomálos, Ivanka Trump y Shashi Tharoor, ya que estas personas son figuras políticas de

# %% [markdown]
# Mientras tanto, esta gráfica nos muestra de que región son las cuentas con más seguidores, y como podemos observar, las principales regiones son China, la India y Estados Unidos. Comparando esta información con los hechos sucedidos durante la pandemia de COVID-19, estos países fueron los más afectados por esta enfermedad.

# %% [markdown]
# # **LOCACIONES**

# %%
cont_loca_inf = inf_10mil['user_location'].value_counts()

data_loca_inf = pd.DataFrame({'Location': cont_loca_inf.index, 'Frequency': cont_loca_inf.values})

print(data_loca_inf.head(20))

plt.figure(figsize=(12, 6))
plt.bar(data_loca_inf['Location'][:20], data_loca_inf['Frequency'][:20])
plt.xlabel('Ubicación de Influencers')
plt.ylabel('Frecuencia')
plt.title('Top 20 Ubicaciones de Influencers')
plt.xticks(rotation=90)
plt.show()
# Out:
#             Location  Frequency
# 0     Washington, DC        118
# 1      United States         70
# 2              India         63
# 3             Global         54
# 4       New York, NY         52
# 5                USA         35
# 6             Canada         34
# 7             London         32
# 8     United Kingdom         27
# 9          Australia         25
# 10  Washington, D.C.         24
# 11      South Africa         23
# 12   Los Angeles, CA         23
# 13  New Delhi, India         23
# 14   London, England         22
# 15         Worldwide         22
# 16        London, UK         21
# 17                UK         21
# 18    Nairobi, Kenya         19
# 19           Ireland         19

# %%
cont_loca_macro = inf_100mil['user_location'].value_counts()

data_loca_macro = pd.DataFrame({'Location': cont_loca_macro.index, 'Frequency': cont_loca_macro.values})

print(data_loca_macro.head(20))

plt.figure(figsize=(12, 6))
plt.bar(data_loca_macro['Location'][:20], data_loca_macro['Frequency'][:20])
plt.xlabel('Ubicación de Macroinfluencers')
plt.ylabel('Frecuencia')
plt.title('Top 20 Ubicaciones de Macroinfluencers')
plt.xticks(rotation=90)
plt.show()
# Out:
#                       Location  Frequency
# 0               Washington, DC         20
# 1                       Global         13
# 2                        India         10
# 3                 New York, NY          9
# 4                 South Africa          8
# 5             New Delhi, India          8
# 6                       Canada          8
# 7             Washington, D.C.          8
# 8                United States          7
# 9   Johannesburg, South Africa          6
# 10              Nairobi, Kenya          6
# 11                  Boston, MA          6
# 12                      London          6
# 13             Los Angeles, CA          5
# 14                   Australia          5
# 15         Geneva, Switzerland          5
# 16                   Worldwide          4
# 17               New York City          4
# 18               Mumbai, India          4
# 19                      Africa          4

# %%
cont_loca_mega = inf_500mil['user_location'].value_counts()

data_loca_mega = pd.DataFrame({'Location': cont_loca_mega.index, 'Frequency': cont_loca_mega.values})

print(data_loca_mega.head(20))

plt.figure(figsize=(12, 6))
plt.bar(data_loca_mega['Location'][:20], data_loca_mega['Frequency'][:20])
plt.xlabel('Ubicación de Megainfluencers')
plt.ylabel('Frecuencia')
plt.title('Top 20 Ubicaciones de Megainfluencers')
plt.xticks(rotation=90)
plt.show()
# Out:
#                 Location  Frequency
# 0                  India          8
# 1       New Delhi, India          5
# 2         Washington, DC          5
# 3       Washington, D.C.          4
# 4           South Africa          4
# 5          Mumbai, India          3
# 6    Manila, Philippines          3
# 7        Kampala, Uganda          2
# 8                Nairobi          2
# 9            Houston, TX          2
# 10  United Arab Emirates          2
# 11             Australia          2
# 12               Chennai          2
# 13           Philippines          2
# 14         United States          2
# 15   Geneva, Switzerland          2
# 16               Atlanta          2
# 17        Beijing, China          2
# 18                Mumbai          2
# 19        Abuja, Nigeria          2

# %%
cont_loca_fam = inf_1mill['user_location'].value_counts()

data_loca_fam= pd.DataFrame({'Location': cont_loca_fam.index, 'Frequency': cont_loca_fam.values})

print(data_loca_fam.head(20))

plt.figure(figsize=(12, 6))
plt.bar(data_loca_fam['Location'][:20], data_loca_fam['Frequency'][:20])
plt.xlabel('Ubicación de famosos')
plt.ylabel('Frecuencia')
plt.title('Top 20 Ubicaciones de Famosos')
plt.xticks(rotation=90)
plt.show()
# Out:
#                           Location  Frequency
# 0                            India         13
# 1                   Beijing, China          4
# 2                     New York, NY          3
# 3                 New Delhi, India          3
# 4                   Washington, DC          3
# 5              Geneva, Switzerland          3
# 6                       London, UK          2
# 7                     South Africa          2
# 8                 Washington, D.C.          2
# 9                      Philippines          2
# 10                     Atlanta, GA          2
# 11                       New Delhi          2
# 12                  Chennai, India          1
# 13  The Pentagon, Washington, D.C.          1
# 14          Houghton, South Africa          1
# 15                          Canada          1
# 16          Kuala Lumpur, Malaysia          1
# 17                      Everywhere          1
# 18  Washington, DC & Cambridge, UK          1
# ...
